# %% [markdown]
# Sorting Data

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Dell\Downloads\pandas_filtering_practice_dataset.csv")
df.head(5)
# Out:
#   Order_ID     Customer       City     Category     Product  Quantity  Price  \
# 0   ORD001  Customer_01      Delhi  Electronics  Smartphone         2   1499
# 1   ORD002  Customer_02       Pune  Electronics    Keyboard         1    499
# 2   ORD003  Customer_03      Delhi       Sports    Football         5   2999
# 3   ORD004  Customer_04    Chennai     Clothing    Sneakers         3   1999
# 4   ORD005  Customer_05  Hyderabad  Electronics      Laptop         3   2499
#
#    Rating Payment_Mode Order_Status  Total_Amount
# 0     2.8          UPI      Pending          2998
# 1     2.7         Card      Pending           499
# 2     3.1         Cash    Delivered         14995
# 3     2.9         Cash    Delivered          5997
# 4     4.0          UPI    Cancelled          7497

# %%
#Q1:Sort the entire DataFrame by Price in ascending order.
df.sort_values('Price')
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 1    ORD002  Customer_02       Pune  Electronics         Keyboard         1
# 28   ORD029  Customer_29      Delhi       Sports      Cricket Bat         5
# 46   ORD047  Customer_47     Mumbai         Home            Chair         4
# 31   ORD032  Customer_32  Bangalore     Clothing            Jeans         1
# 43   ORD044  Customer_44      Delhi     Clothing           Jacket         3
# 42   ORD043  Customer_43      Delhi  Electronics           Laptop         2
# 32   ORD033  Customer_33  Hyderabad       Sports         Football         1
# 33   ORD034  Customer_34    Chennai  Electronics       Headphones         4
# 40   ORD041  Customer_41  Hyderabad       Sports         Yoga Mat         1
# 15   ORD016  Customer_16    Kolkata       Sports         Yoga Mat         3
# 49   ORD050  Customer_50      Delhi         Home            Chair         3
# ...

# %%
#Q2:Sort the entire DataFrame by Price in descending order.
df.sort_values('Price',ascending=False)
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 24   ORD025  Customer_25     Mumbai       Sports    Tennis Racket         2
# 19   ORD020  Customer_20     Mumbai  Electronics           Laptop         1
# 14   ORD015  Customer_15  Hyderabad  Electronics         Keyboard         5
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 25   ORD026  Customer_26    Chennai  Electronics         Keyboard         3
# 29   ORD030  Customer_30  Hyderabad        Books        SQL Guide         2
# 20   ORD021  Customer_21       Pune        Books     Data Science         3
# 2    ORD003  Customer_03      Delhi       Sports         Football         5
# 7    ORD008  Customer_08  Hyderabad  Electronics       Smartphone         4
# 48   ORD049  Customer_49  Bangalore         Home            Chair         3
# 45   ORD046  Customer_46  Hyderabad     Clothing          T-Shirt         2
# ...

# %%
#Q3:Sort the DataFrame by Rating from lowest to highest.
df.sort_values('Rating')
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 22   ORD023  Customer_23      Delhi         Home             Lamp         5
# 47   ORD048  Customer_48  Bangalore        Books  AI Fundamentals         2
# 10   ORD011  Customer_11    Kolkata  Electronics       Smartphone         4
# 1    ORD002  Customer_02       Pune  Electronics         Keyboard         1
# 11   ORD012  Customer_12  Hyderabad        Books        SQL Guide         2
# 0    ORD001  Customer_01      Delhi  Electronics       Smartphone         2
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 7    ORD008  Customer_08  Hyderabad  Electronics       Smartphone         4
# 3    ORD004  Customer_04    Chennai     Clothing         Sneakers         3
# 26   ORD027  Customer_27  Hyderabad  Electronics       Smartphone         1
# 2    ORD003  Customer_03      Delhi       Sports         Football         5
# ...

# %%
#Q4:Sort the DataFrame by Rating from highest to lowest.
df.sort_values('Rating',ascending=False)
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 12   ORD013  Customer_13       Pune        Books        SQL Guide         3
# 28   ORD029  Customer_29      Delhi       Sports      Cricket Bat         5
# 33   ORD034  Customer_34    Chennai  Electronics       Headphones         4
# 20   ORD021  Customer_21       Pune        Books     Data Science         3
# 29   ORD030  Customer_30  Hyderabad        Books        SQL Guide         2
# 44   ORD045  Customer_45  Bangalore  Electronics         Keyboard         5
# 34   ORD035  Customer_35      Delhi       Sports      Cricket Bat         4
# 43   ORD044  Customer_44      Delhi     Clothing           Jacket         3
# 27   ORD028  Customer_28     Mumbai        Books  AI Fundamentals         4
# 18   ORD019  Customer_19  Hyderabad         Home            Chair         1
# 5    ORD006  Customer_06      Delhi       Sports    Tennis Racket         1
# ...

# %%
#Q5:Sort the DataFrame by Quantity in descending order.
df.sort_values('Quantity',ascending=False)
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 8    ORD009  Customer_09    Chennai         Home            Chair         5
# 28   ORD029  Customer_29      Delhi       Sports      Cricket Bat         5
# 14   ORD015  Customer_15  Hyderabad  Electronics         Keyboard         5
# 39   ORD040  Customer_40  Bangalore     Clothing           Jacket         5
# 22   ORD023  Customer_23      Delhi         Home             Lamp         5
# 9    ORD010  Customer_10  Hyderabad        Books  AI Fundamentals         5
# 16   ORD017  Customer_17    Chennai  Electronics       Smartphone         5
# 44   ORD045  Customer_45  Bangalore  Electronics         Keyboard         5
# 2    ORD003  Customer_03      Delhi       Sports         Football         5
# 7    ORD008  Customer_08  Hyderabad  Electronics       Smartphone         4
# 33   ORD034  Customer_34    Chennai  Electronics       Headphones         4
# ...

# %%
#Q6:Sort the DataFrame by Total_Amount from highest to lowest.
df.sort_values('Total_Amount',ascending=False)
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 14   ORD015  Customer_15  Hyderabad  Electronics         Keyboard         5
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 2    ORD003  Customer_03      Delhi       Sports         Football         5
# 7    ORD008  Customer_08  Hyderabad  Electronics       Smartphone         4
# 34   ORD035  Customer_35      Delhi       Sports      Cricket Bat         4
# 20   ORD021  Customer_21       Pune        Books     Data Science         3
# 25   ORD026  Customer_26    Chennai  Electronics         Keyboard         3
# 24   ORD025  Customer_25     Mumbai       Sports    Tennis Racket         2
# 30   ORD031  Customer_31  Hyderabad  Electronics       Smartphone         4
# 10   ORD011  Customer_11    Kolkata  Electronics       Smartphone         4
# 48   ORD049  Customer_49  Bangalore         Home            Chair         3
# ...

# %%
#Q7:Sort the DataFrame by Total_Amount from lowest to highest.
df.sort_values('Total_Amount')
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 1    ORD002  Customer_02       Pune  Electronics         Keyboard         1
# 31   ORD032  Customer_32  Bangalore     Clothing            Jeans         1
# 32   ORD033  Customer_33  Hyderabad       Sports         Football         1
# 40   ORD041  Customer_41  Hyderabad       Sports         Yoga Mat         1
# 42   ORD043  Customer_43      Delhi  Electronics           Laptop         2
# 38   ORD039  Customer_39      Delhi       Sports         Yoga Mat         1
# 13   ORD014  Customer_14      Delhi        Books    Python Basics         1
# 43   ORD044  Customer_44      Delhi     Clothing           Jacket         3
# 36   ORD037  Customer_37       Pune        Books    Python Basics         1
# 26   ORD027  Customer_27  Hyderabad  Electronics       Smartphone         1
# 23   ORD024  Customer_24      Delhi  Electronics       Smartphone         1
# ...

# %%
#Q8:Sort by Price descending and display only:Order_ID,Product,Price
df.sort_values('Price',ascending=False)[['Order_ID','Product','Price']]
# Out:
#    Order_ID          Product  Price
# 24   ORD025    Tennis Racket   3999
# 19   ORD020           Laptop   3999
# 14   ORD015         Keyboard   3999
# 21   ORD022  AI Fundamentals   3999
# 25   ORD026         Keyboard   2999
# 29   ORD030        SQL Guide   2999
# 20   ORD021     Data Science   2999
# 2    ORD003         Football   2999
# 7    ORD008       Smartphone   2499
# 48   ORD049            Chair   2499
# 45   ORD046          T-Shirt   2499
# 4    ORD005           Laptop   2499
# 34   ORD035      Cricket Bat   2499
# 17   ORD018         Football   2499
# 18   ORD019            Chair   2499
# 5    ORD006    Tennis Racket   1999
# 11   ORD012        SQL Guide   1999
# 30   ORD031       Smartphone   1999
# 3    ORD004         Sneakers   1999
# 35   ORD036         Sneakers   1999
# 10   ORD011       Smartphone   1999
# 36   ORD037    Python Basics   1499
# 26   ORD027       Smartphone   1499
# 39   ORD040           Jacket   1499
# 47   ORD048  AI Fundamentals   1499
# ...

# %%
#Q9:Sort by Rating descending and display:Customer,Product,Rating
df.sort_values('Rating',ascending=False)[['Customer','Product','Rating']]
# Out:
#        Customer          Product  Rating
# 12  Customer_13        SQL Guide     5.0
# 28  Customer_29      Cricket Bat     4.9
# 33  Customer_34       Headphones     4.9
# 20  Customer_21     Data Science     4.9
# 29  Customer_30        SQL Guide     4.8
# 44  Customer_45         Keyboard     4.8
# 34  Customer_35      Cricket Bat     4.8
# 43  Customer_44           Jacket     4.7
# 27  Customer_28  AI Fundamentals     4.7
# 18  Customer_19            Chair     4.7
# 5   Customer_06    Tennis Racket     4.6
# 32  Customer_33         Football     4.6
# 42  Customer_43           Laptop     4.6
# 46  Customer_47            Chair     4.6
# 45  Customer_46          T-Shirt     4.5
# 19  Customer_20           Laptop     4.5
# 24  Customer_25    Tennis Racket     4.5
# 31  Customer_32            Jeans     4.4
# 41  Customer_42       Headphones     4.4
# 17  Customer_18         Football     4.4
# 6   Customer_07          T-Shirt     4.4
# 39  Customer_40           Jacket     4.3
# ...

# %%
#Q10:Sort by Total_Amount descending and display the top 5 orders.
df.sort_values('Total_Amount',ascending=False).head(5)
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 14   ORD015  Customer_15  Hyderabad  Electronics         Keyboard         5
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 2    ORD003  Customer_03      Delhi       Sports         Football         5
# 7    ORD008  Customer_08  Hyderabad  Electronics       Smartphone         4
# 34   ORD035  Customer_35      Delhi       Sports      Cricket Bat         4
#
#     Price  Rating Payment_Mode Order_Status  Total_Amount
# 14   3999     3.8          UPI    Delivered         19995
# 21   3999     2.8         Card    Delivered         15996
# 2    2999     3.1         Cash    Delivered         14995
# 7    2499     2.9         Cash    Delivered          9996
# 34   2499     4.8         Card    Delivered          9996

# %%
#Q11:Sort by Quantity ascending and display:Order_ID,Product,Quantity
df.sort_values('Quantity')[['Order_ID','Product','Quantity']]
# Out:
#    Order_ID          Product  Quantity
# 36   ORD037    Python Basics         1
# 23   ORD024       Smartphone         1
# 26   ORD027       Smartphone         1
# 13   ORD014    Python Basics         1
# 31   ORD032            Jeans         1
# 32   ORD033         Football         1
# 19   ORD020           Laptop         1
# 38   ORD039         Yoga Mat         1
# 18   ORD019            Chair         1
# 6    ORD007          T-Shirt         1
# 5    ORD006    Tennis Racket         1
# 1    ORD002         Keyboard         1
# 40   ORD041         Yoga Mat         1
# 35   ORD036         Sneakers         2
# 42   ORD043           Laptop         2
# 45   ORD046          T-Shirt         2
# 29   ORD030        SQL Guide         2
# 47   ORD048  AI Fundamentals         2
# 0    ORD001       Smartphone         2
# 24   ORD025    Tennis Racket         2
# 17   ORD018         Football         2
# 11   ORD012        SQL Guide         2
# 20   ORD021     Data Science         3
# ...

# %%
#Q12:Sort by Price descending and display only the top 3 most expensive products.
df.sort_values('Price',ascending=False).head(3)
# Out:
#    Order_ID     Customer       City     Category        Product  Quantity  \
# 24   ORD025  Customer_25     Mumbai       Sports  Tennis Racket         2
# 19   ORD020  Customer_20     Mumbai  Electronics         Laptop         1
# 14   ORD015  Customer_15  Hyderabad  Electronics       Keyboard         5
#
#     Price  Rating Payment_Mode Order_Status  Total_Amount
# 24   3999     4.5         Card    Delivered          7998
# 19   3999     4.5         Card    Delivered          3999
# 14   3999     3.8          UPI    Delivered         19995

# %%
#Q13:Sort by City alphabetically, and within each city sort Price from highest to lowest.
df.sort_values(['City','Price'],ascending=[True,False])
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 48   ORD049  Customer_49  Bangalore         Home            Chair         3
# 35   ORD036  Customer_36  Bangalore     Clothing         Sneakers         2
# 39   ORD040  Customer_40  Bangalore     Clothing           Jacket         5
# 47   ORD048  Customer_48  Bangalore        Books  AI Fundamentals         2
# 41   ORD042  Customer_42  Bangalore  Electronics       Headphones         3
# 44   ORD045  Customer_45  Bangalore  Electronics         Keyboard         5
# 31   ORD032  Customer_32  Bangalore     Clothing            Jeans         1
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 25   ORD026  Customer_26    Chennai  Electronics         Keyboard         3
# 3    ORD004  Customer_04    Chennai     Clothing         Sneakers         3
# 6    ORD007  Customer_07    Chennai     Clothing          T-Shirt         1
# ...

# %%
#Q14:Sort by Category alphabetically, and within each category sort Rating from highest to lowest
df.sort_values(['Category','Rating'],ascending=[True,False])
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 12   ORD013  Customer_13       Pune        Books        SQL Guide         3
# 20   ORD021  Customer_21       Pune        Books     Data Science         3
# 29   ORD030  Customer_30  Hyderabad        Books        SQL Guide         2
# 27   ORD028  Customer_28     Mumbai        Books  AI Fundamentals         4
# 9    ORD010  Customer_10  Hyderabad        Books  AI Fundamentals         5
# 13   ORD014  Customer_14      Delhi        Books    Python Basics         1
# 36   ORD037  Customer_37       Pune        Books    Python Basics         1
# 11   ORD012  Customer_12  Hyderabad        Books        SQL Guide         2
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 47   ORD048  Customer_48  Bangalore        Books  AI Fundamentals         2
# 43   ORD044  Customer_44      Delhi     Clothing           Jacket         3
# ...

# %%
#Q15:Sort by Order_Status alphabetically, and within each status sort Total_Amount from highest to lowest.
df.sort_values(['Order_Status','Total_Amount'],ascending=[True,False])
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 4    ORD005  Customer_05  Hyderabad  Electronics           Laptop         3
# 29   ORD030  Customer_30  Hyderabad        Books        SQL Guide         2
# 27   ORD028  Customer_28     Mumbai        Books  AI Fundamentals         4
# 47   ORD048  Customer_48  Bangalore        Books  AI Fundamentals         2
# 15   ORD016  Customer_16    Kolkata       Sports         Yoga Mat         3
# 42   ORD043  Customer_43      Delhi  Electronics           Laptop         2
# 14   ORD015  Customer_15  Hyderabad  Electronics         Keyboard         5
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 2    ORD003  Customer_03      Delhi       Sports         Football         5
# 7    ORD008  Customer_08  Hyderabad  Electronics       Smartphone         4
# 34   ORD035  Customer_35      Delhi       Sports      Cricket Bat         4
# ...

# %%
#Q16:Sort by Payment_Mode alphabetically, and within each payment mode sort Price from lowest to highest.
df.sort_values(['Payment_Mode','Price'],ascending=[True,True])
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 1    ORD002  Customer_02       Pune  Electronics         Keyboard         1
# 28   ORD029  Customer_29      Delhi       Sports      Cricket Bat         5
# 42   ORD043  Customer_43      Delhi  Electronics           Laptop         2
# 43   ORD044  Customer_44      Delhi     Clothing           Jacket         3
# 46   ORD047  Customer_47     Mumbai         Home            Chair         4
# 15   ORD016  Customer_16    Kolkata       Sports         Yoga Mat         3
# 33   ORD034  Customer_34    Chennai  Electronics       Headphones         4
# 8    ORD009  Customer_09    Chennai         Home            Chair         5
# 44   ORD045  Customer_45  Bangalore  Electronics         Keyboard         5
# 12   ORD013  Customer_13       Pune        Books        SQL Guide         3
# 36   ORD037  Customer_37       Pune        Books    Python Basics         1
# ...

# %%
#Q17:Sort by City ascending and then Total_Amount descending.
df.sort_values(['City','Total_Amount'],ascending=[True,False])
# Out:
#    Order_ID     Customer       City     Category          Product  Quantity  \
# 48   ORD049  Customer_49  Bangalore         Home            Chair         3
# 39   ORD040  Customer_40  Bangalore     Clothing           Jacket         5
# 44   ORD045  Customer_45  Bangalore  Electronics         Keyboard         5
# 35   ORD036  Customer_36  Bangalore     Clothing         Sneakers         2
# 47   ORD048  Customer_48  Bangalore        Books  AI Fundamentals         2
# 41   ORD042  Customer_42  Bangalore  Electronics       Headphones         3
# 31   ORD032  Customer_32  Bangalore     Clothing            Jeans         1
# 21   ORD022  Customer_22    Chennai        Books  AI Fundamentals         4
# 25   ORD026  Customer_26    Chennai  Electronics         Keyboard         3
# 3    ORD004  Customer_04    Chennai     Clothing         Sneakers         3
# 8    ORD009  Customer_09    Chennai         Home            Chair         5
# ...

# %%
#Q18:Find the 5 highest-value orders based on Total_Amount.
df.sort_values('Total_Amount',ascending=False).head(5)[['Order_ID', 'Customer', 'City', 'Product', 'Total_Amount']]
# Out:
#    Order_ID     Customer       City          Product  Total_Amount
# 14   ORD015  Customer_15  Hyderabad         Keyboard         19995
# 21   ORD022  Customer_22    Chennai  AI Fundamentals         15996
# 2    ORD003  Customer_03      Delhi         Football         14995
# 7    ORD008  Customer_08  Hyderabad       Smartphone          9996
# 34   ORD035  Customer_35      Delhi      Cricket Bat          9996

# %%
#Q19:Find the 3 most expensive products based on Price.
df.sort_values('Price',ascending=False).head(3)[['Product','Price']]
# Out:
#           Product  Price
# 24  Tennis Racket   3999
# 19         Laptop   3999
# 14       Keyboard   3999

# %%
#Q20:Find the 5 orders with the highest ratings
df.sort_values('Rating',ascending=False).head(5)[['Order_ID', 'Customer', 'Product', 'Rating']]
# Out:
#    Order_ID     Customer       Product  Rating
# 12   ORD013  Customer_13     SQL Guide     5.0
# 28   ORD029  Customer_29   Cricket Bat     4.9
# 33   ORD034  Customer_34    Headphones     4.9
# 20   ORD021  Customer_21  Data Science     4.9
# 29   ORD030  Customer_30     SQL Guide     4.8

# %%
#Q21:Find the 3 orders with the largest quantities.
df.sort_values('Quantity',ascending=False).head(3)[['Order_ID', 'Product', 'Quantity']]
# Out:
#    Order_ID      Product  Quantity
# 8    ORD009        Chair         5
# 28   ORD029  Cricket Bat         5
# 14   ORD015     Keyboard         5

# %%
#Q22:Sort the data by Category ascending and Total_Amount descending, then display only:Category, Product, Quantity, Total_Amount
df.sort_values(['Category','Total_Amount'],ascending=[True,False])[['Category','Product','Quantity','Total_Amount']]
# Out:
#        Category          Product  Quantity  Total_Amount
# 21        Books  AI Fundamentals         4         15996
# 20        Books     Data Science         3          8997
# 9         Books  AI Fundamentals         5          7495
# 29        Books        SQL Guide         2          5998
# 27        Books  AI Fundamentals         4          5996
# 12        Books        SQL Guide         3          4497
# 11        Books        SQL Guide         2          3998
# 47        Books  AI Fundamentals         2          2998
# 36        Books    Python Basics         1          1499
# 13        Books    Python Basics         1           999
# 39     Clothing           Jacket         5          7495
# 3      Clothing         Sneakers         3          5997
# 45     Clothing          T-Shirt         2          4998
# 35     Clothing         Sneakers         2          3998
# 6      Clothing          T-Shirt         1          1499
# ...

# %%
#Q23:Sort by Order_Status and then Rating descending. Display:Order_ID, Product, Rating, Order_Status
df.sort_values(['Order_Status','Rating'],ascending=[True,False])[['Order_ID','Product','Rating','Order_Status']]
# Out:
#    Order_ID          Product  Rating Order_Status
# 29   ORD030        SQL Guide     4.8    Cancelled
# 27   ORD028  AI Fundamentals     4.7    Cancelled
# 42   ORD043           Laptop     4.6    Cancelled
# 4    ORD005           Laptop     4.0    Cancelled
# 15   ORD016         Yoga Mat     3.2    Cancelled
# 47   ORD048  AI Fundamentals     2.6    Cancelled
# 20   ORD021     Data Science     4.9    Delivered
# 28   ORD029      Cricket Bat     4.9    Delivered
# 34   ORD035      Cricket Bat     4.8    Delivered
# 44   ORD045         Keyboard     4.8    Delivered
# 18   ORD019            Chair     4.7    Delivered
# 43   ORD044           Jacket     4.7    Delivered
# 46   ORD047            Chair     4.6    Delivered
# 19   ORD020           Laptop     4.5    Delivered
# 24   ORD025    Tennis Racket     4.5    Delivered
# 45   ORD046          T-Shirt     4.5    Delivered
# 6    ORD007          T-Shirt     4.4    Delivered
# 31   ORD032            Jeans     4.4    Delivered
# ...

# %%
#Q24:Sort by City ascending and Price descending. Display:City, Product, Price
df.sort_values(['City','Price'],ascending=[True,False])[['City','Product','Price']]
# Out:
#          City          Product  Price
# 48  Bangalore            Chair   2499
# 35  Bangalore         Sneakers   1999
# 39  Bangalore           Jacket   1499
# 47  Bangalore  AI Fundamentals   1499
# 41  Bangalore       Headphones    999
# 44  Bangalore         Keyboard    999
# 31  Bangalore            Jeans    499
# 21    Chennai  AI Fundamentals   3999
# 25    Chennai         Keyboard   2999
# 3     Chennai         Sneakers   1999
# 6     Chennai          T-Shirt   1499
# 8     Chennai            Chair    999
# 16    Chennai       Smartphone    999
# 33    Chennai       Headphones    799
# 2       Delhi         Football   2999
# 34      Delhi      Cricket Bat   2499
# 5       Delhi    Tennis Racket   1999
# 0       Delhi       Smartphone   1499
# 22      Delhi             Lamp   1499
# 23      Delhi       Smartphone   1499
# 13      Delhi    Python Basics    999
# 38      Delhi         Yoga Mat    999
# 49      Delhi            Chair    999
# 28      Delhi      Cricket Bat    499
# ...

# %%
#Q25:Sort by Payment_Mode ascending and Total_Amount descending. Display:Payment_Mode, Order_ID, Total_Amount
df.sort_values(['Payment_Mode','Total_Amount'],ascending=[True,False])[['Payment_Mode','Order_ID','Total_Amount']]
# Out:
#    Payment_Mode Order_ID  Total_Amount
# 21         Card   ORD022         15996
# 34         Card   ORD035          9996
# 20         Card   ORD021          8997
# 24         Card   ORD025          7998
# 39         Card   ORD040          7495
# 29         Card   ORD030          5998
# 8          Card   ORD009          4995
# 44         Card   ORD045          4995
# 12         Card   ORD013          4497
# 19         Card   ORD020          3999
# 33         Card   ORD034          3196
# 47         Card   ORD048          2998
# 28         Card   ORD029          2495
# 15         Card   ORD016          2397
# 46         Card   ORD047          1996
# 36         Card   ORD037          1499
# 43         Card   ORD044          1497
# 42         Card   ORD043           998
# 1          Card   ORD002           499
# 2          Cash   ORD003         14995
# 7          Cash   ORD008          9996
# 10         Cash   ORD011          7996
# 3          Cash   ORD004          5997
# ...

# %%
'''Q26:Create a result that shows the top 5 highest-value orders, but display only:
Order_ID, Customer, City, Product, Quantity, Price, Rating, Total_Amount
Sort the result by Total_Amount from highest to lowest.'''

df.sort_values('Total_Amount',ascending=False).head(5)[['Order_ID', 'Customer', 'City',
            'Product', 'Quantity', 'Price', 'Rating', 'Total_Amount']]
# Out:
#    Order_ID     Customer       City          Product  Quantity  Price  Rating  \
# 14   ORD015  Customer_15  Hyderabad         Keyboard         5   3999     3.8
# 21   ORD022  Customer_22    Chennai  AI Fundamentals         4   3999     2.8
# 2    ORD003  Customer_03      Delhi         Football         5   2999     3.1
# 7    ORD008  Customer_08  Hyderabad       Smartphone         4   2499     2.9
# 34   ORD035  Customer_35      Delhi      Cricket Bat         4   2499     4.8
#
#     Total_Amount
# 14         19995
# 21         15996
# 2          14995
# 7           9996
# 34          9996
