# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Dell\Downloads\pandas_filtering_practice_dataset.csv")
df.head(5)
# Out:
#   Order_ID     Customer       City     Category     Product  Quantity  Price  \
# 0   ORD001  Customer_01      Delhi  Electronics  Smartphone         2   1499
# 1   ORD002  Customer_02       Pune  Electronics    Keyboard         1    499
# 2   ORD003  Customer_03      Delhi       Sports    Football         5   2999
# 3   ORD004  Customer_04    Chennai     Clothing    Sneakers         3   1999
# 4   ORD005  Customer_05  Hyderabad  Electronics      Laptop         3   2499
#
#    Rating Payment_Mode Order_Status  Total_Amount
# 0     2.8          UPI      Pending          2998
# 1     2.7         Card      Pending           499
# 2     3.1         Cash    Delivered         14995
# 3     2.9         Cash    Delivered          5997
# 4     4.0          UPI    Cancelled          7497

# %%
#Q1:Find how many orders came from each City.
df['City'].value_counts()
# Out:
# City
# Delhi        12
# Hyderabad    12
# Chennai       7
# Bangalore     7
# Pune          5
# Mumbai        5
# Kolkata       2
# Name: count, dtype: int64

# %%
#Q2:Find how many orders belong to each Category.
df['Category'].value_counts()
# Out:
# Category
# Electronics    17
# Sports         10
# Books          10
# Clothing        7
# Home            6
# Name: count, dtype: int64

# %%
#Q3:Find how many orders were made using each Payment_Mode.
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Card           19
# UPI            14
# Cash           10
# Net Banking     7
# Name: count, dtype: int64

# %%
#Q4:Find how many orders have each Order_Status.
df['Order_Status'].value_counts()
# Out:
# Order_Status
# Delivered    31
# Pending      13
# Cancelled     6
# Name: count, dtype: int64

# %%
#Q5:Find how many orders were placed for each Product.
df['Product'].value_counts()
# Out:
# Product
# Smartphone         8
# Chair              5
# Keyboard           4
# AI Fundamentals    4
# Yoga Mat           3
# SQL Guide          3
# Laptop             3
# Football           3
# T-Shirt            2
# Tennis Racket      2
# Sneakers           2
# Python Basics      2
# Cricket Bat        2
# Headphones         2
# Jacket             2
# Data Science       1
# Lamp               1
# Jeans              1
# Name: count, dtype: int64

# %%
#Q6:Find how many orders each Customer has made.
df['Customer'].value_counts()
# Out:
# Customer
# Customer_01    1
# Customer_38    1
# Customer_28    1
# Customer_29    1
# Customer_30    1
# Customer_31    1
# Customer_32    1
# Customer_33    1
# Customer_34    1
# Customer_35    1
# Customer_36    1
# Customer_37    1
# Customer_39    1
# Customer_02    1
# Customer_40    1
# Customer_41    1
# Customer_42    1
# Customer_43    1
# Customer_44    1
# Customer_45    1
# Customer_46    1
# Customer_47    1
# Customer_48    1
# Customer_49    1
# Customer_27    1
# Customer_26    1
# Customer_25    1
# Customer_24    1
# Customer_03    1
# Customer_04    1
# Customer_05    1
# Customer_06    1
# Customer_07    1
# Customer_08    1
# Customer_09    1
# Customer_10    1
# Customer_11    1
# Customer_12    1
# Customer_13    1
# Customer_14    1
# Customer_15    1
# Customer_16    1
# Customer_17    1
# Customer_18    1
# Customer_19    1
# Customer_20    1
# Customer_21    1
# Customer_22    1
# Customer_23    1
# Customer_50    1
# Name: count, dtype: int64

# %%
#Q7:Find how many times each Rating appears in the dataset.
df['Rating'].value_counts()
# Out:
# Rating
# 4.6    4
# 4.4    4
# 3.8    4
# 2.8    3
# 4.1    3
# 3.6    3
# 4.8    3
# 4.9    3
# 4.5    3
# 4.7    3
# 3.2    3
# 2.7    2
# 4.0    2
# 2.9    2
# 5.0    1
# 4.2    1
# 2.5    1
# 3.5    1
# 3.0    1
# 3.1    1
# 4.3    1
# 2.6    1
# Name: count, dtype: int64

# %%
#Q8:Find the top 5 most frequently ordered Products.
df['Product'].value_counts().head(5)
# Out:
# Product
# Smartphone         8
# Chair              5
# Keyboard           4
# AI Fundamentals    4
# Yoga Mat           3
# Name: count, dtype: int64

# %%
#Q9:Find the top 3 Cities with the highest number of orders.
df['City'].value_counts().head(3)
# Out:
# City
# Delhi        12
# Hyderabad    12
# Chennai       7
# Name: count, dtype: int64

# %%
#Q10:Find the least frequently used Payment_Mode.
df['Payment_Mode'].value_counts(ascending=True).head(1)
# Out:
# Payment_Mode
# Net Banking    7
# Name: count, dtype: int64

# %%
#Q11:Find the most common Order_Status.
df['Order_Status'].value_counts().head(1)
# Out:
# Order_Status
# Delivered    31
# Name: count, dtype: int64

# %%
#Q12:Find the 5 most common Customers based on number of orders.
df['Customer'].value_counts().head(5)
# Out:
# Customer
# Customer_01    1
# Customer_38    1
# Customer_28    1
# Customer_29    1
# Customer_30    1
# Name: count, dtype: int64

# %%
#Q13:Find how many orders belong to each Category, including the percentage of total orders.
df['Category'].value_counts(normalize=True)*100
# Out:
# Category
# Electronics    34.0
# Sports         20.0
# Books          20.0
# Clothing       14.0
# Home           12.0
# Name: proportion, dtype: float64

# %%
#Q14:Find the percentage distribution of each Payment_Mode
df['Payment_Mode'].value_counts(normalize=True)*100
# Out:
# Payment_Mode
# Card           38.0
# UPI            28.0
# Cash           20.0
# Net Banking    14.0
# Name: proportion, dtype: float64

# %%
#Q15:For orders where Order_Status == 'Delivered', find the number of orders from each City.
df[df['Order_Status'] == 'Delivered']['City'].value_counts()
# Out:
# City
# Hyderabad    8
# Delhi        7
# Chennai      6
# Bangalore    4
# Mumbai       3
# Pune         2
# Kolkata      1
# Name: count, dtype: int64

# %%
#Q16:For orders where Category == 'Electronics', find the number of orders for each Product.
df[df['Category']=='Electronics']['Product'].value_counts()
# Out:
# Product
# Smartphone    8
# Keyboard      4
# Laptop        3
# Headphones    2
# Name: count, dtype: int64

# %%
#Q17:For orders where Payment_Mode == 'UPI', find the number of orders from each City
df[df['Payment_Mode']=='UPI']['City'].value_counts()
# Out:
# City
# Hyderabad    4
# Delhi        3
# Chennai      3
# Bangalore    2
# Pune         1
# Mumbai       1
# Name: count, dtype: int64

# %%
#Q18:For orders where Rating >= 4, find the number of orders for each Category.
df[df['Rating']>=4]['Category'].value_counts()
# Out:
# Category
# Sports         7
# Electronics    6
# Books          6
# Clothing       5
# Home           4
# Name: count, dtype: int64

# %%
#Q19:For orders where Order_Status == 'Cancelled', find the most frequently occurring Payment_Mode.
df[df['Order_Status']=='Cancelled']['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Card    4
# UPI     2
# Name: count, dtype: int64

# %%
#Q20:For orders where Category == 'Clothing', find the top 3 most ordered Products.
df[df['Category']=='Clothing']['Product'].value_counts().head(3)
# Out:
# Product
# Sneakers    2
# T-Shirt     2
# Jacket      2
# Name: count, dtype: int64
