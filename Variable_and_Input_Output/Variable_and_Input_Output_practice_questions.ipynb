# %%
#question1:print Hello World!

print("Hello World!")
# Out:
# Hello World!

# %%
#q2:print your name,college name and branch
a=input("Enter name:")
b=input("Enter college name:")
c=input("Enter branch:")
print(a)
print(b)
print(c)
# Out:
# Enter name: Pallavi
# Enter college name: CCSIT
# Enter branch: Computer Science
# Pallavi
# CCSIT
# Computer Science

# %%
#q3: take name as input and print Hello,<name>
n=input("Enter name:")
print("Hello",(n))
# Out:
# Enter name: Pallavi
# Hello Pallavi

# %%
#q4:take two integers as input and print their sum
a=int(input("Enter number:"))
b=int(input("Enter number:"))
print(a+b)
# Out:
# Enter number: 23
# Enter number: 12
# 35

# %%
#q5:take two integers as input and print their difference
a=int(input("Enter number:"))
b=int(input("Enter number:"))
print(a-b)
# Out:
# Enter number: 56
# Enter number: 23
# 33

# %%
#q6: Take two integers and print their product and quotient
a=int(input("Enter number:"))
b=int(input("Enter number:"))
print("Product is:",a*b)
print("Quotient is:",a%b)
# Out:
# Enter number: 12
# Enter number: 5
# Product is: 60
# Quotient is: 2

# %%
#q7: Take the length and width of a rectangle and print its area
L=int(input("Enter length:"))
B=int(input("Enter breadth:"))
print("Area of rectangle is :",L*B)
# Out:
# Enter length: 8
# Enter breadth: 4
# Area of rectangle is : 32

# %%
#q8: Take the radius of circle and print its area
r=int(input("Enter radius:"))
print(f"Area of circle is:{3.14*r*r}")
# Out:
# Enter radius: 5
# Area of circle is:78.5

# %%
#q9: convert temperature from celsius to farenheit
celsius=int(input("Enter temperature in celsius:"))
farenheit=(9/5)*celsius+32            #formula to convert celsius to farenheit
print("Temperature in farenheit is:", farenheit)
# Out:
# Enter temperature in celsius: 25
# Temperature in farenheit is: 77.0

# %%
#q10: Take 5 numbers as input and print their average
num1=int(input("Enter number 1:"))
num2=int(input("Enter number 2:"))
num3=int(input("Enter number 3:"))
num4=int(input("Enter number 4:"))
num5=int(input("Enter number 5:"))
average=(num1+num2+num3+num4+num5)/5
print("Average is :",average)
# Out:
# Enter number 1: 12
# Enter number 2: 23
# Enter number 3: 21
# Enter number 4: 32
# Enter number 5: 26
# Average is : 22.8

# %%
#q11: Take a number and print its square and cube
n=int(input("Enter number:"))
print("Square is:", n**2)      #prints square
print("Cube is :", n**3)       #prints cube
# Out:
# Enter number: 5
# Square is: 25
# Cube is : 125

# %%
#q12: Convert kilometers to meters and centimeters
km= int(input("Enter kilometes:"))
meters= km*1000                #formula to convert kms into ms
centimeters=km*100000             #formula to convert kms into cms
print("meters is :", meters)
print("centimeters is:", centimeters)
# Out:
# Enter kilometes: 200
# meters is : 200000
# centimeters is: 20000000

# %%
#q13: Convert minutes into hours and minutes
minutes= int(input("Enter minutes:"))
hours=minutes//60                           #gives complete hours
remaining_minutes=minutes%60                  #gives the remaining minutes
print(hours,"hours", remaining_minutes,"minutes")
# Out:
# Enter minutes: 145
# 2 hours 25 minutes

# %%
#q14: Take the price and quantity of an item and caluclate the total bill
price=int(input("Enter price of item:"))
quantity= int(input("Enter quantity:"))

print("Total bill is:", price*quantity)            #gives total bill of an item
# Out:
# Enter price of item: 299
# Enter quantity: 15
# Total bill is: 4485

# %%
#q15: Take a three digit number and print the sum of its digits
n=int(input("Enter three digit number:"))
digit1=n%10          #gives the remainder
n = n//10               #removes the last digit
digit2=n%10
n = n//10
digit3=n%10

sum_of_digits= digit1+digit2+digit3
print("Sum of digits=", sum_of_digits)
# Out:
# Enter three digit number: 456
# Sum of digits= 15

# %%
#q16: Calculate simple interest using prinicipal, rate and time
p=int(input("Enter principal:"))
r= int(input("Enter rate:"))
t= int(input("Enter time:"))
simple_interest = (p*r*t)/100           #formula to get simple interest
print("simple interest is:", simple_interest)
# Out:
# Enter principal: 10000
# Enter rate: 5
# Enter time: 2
# simple interest is: 1000.0

# %%
#q17: Swap two numbers using a third variable
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
temp=a
a=b
b=temp
print("After swapping:")
print("a=",a)
print("b=", b)
# Out:
# Enter first number: 5
# Enter second number: 7
# After swapping:
# a= 7
# b= 5

# %%
#q18:  Swap two numbers using a third variable
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))

a=a+b
b=a-b
a=a-b
print("After swapping:")
print("a=",a)
print("b=", b)
# Out:
# Enter first number: 5
# Enter second number: 3
# After swapping:
# a= 3
# b= 5

# %%
#q19: Take age as input and print how many years are left until the user turns 100
age=int(input("Enter age:"))
years_left=100-age
print("Years left", years_left)
# Out:
# Enter age: 55
# Years left 45

# %%
#q20:take student's name and marks in 5 subject then print name, total marks and average marks
name=input("Enter name:")
marks1= int(input("Enter marks in subject 1:"))
marks2= int(input("Enter marks in subject 2:"))
marks3= int(input("Enter marks in subject 3:"))
marks4= int(input("Enter marks in subject 4:"))
marks5= int(input("Enter marks in subject 5:"))
total_marks=marks1+marks2+marks3+marks4+marks5
average=(marks1+marks2+marks3+marks4+marks5)/5
print("Student's name is:",name)
print("Total marks=", total_marks)
print("Average is=", average)
# Out:
# Enter name: Pallavi
# Enter marks in subject 1: 95
# Enter marks in subject 2: 79
# Enter marks in subject 3: 84
# Enter marks in subject 4: 96
# Enter marks in subject 5: 85
# Student's name is: Pallavi
# Total marks= 439
# Average is= 87.8
